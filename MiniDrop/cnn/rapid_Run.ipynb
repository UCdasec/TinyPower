# %%
# %run "cnn/test.py" -i /home/mabon/Tiny_power/datasets/em/xmega/X2_K2_150k_L11.npz -m /home/mabon/Tiny_power/models/custom_prunded/HW/xmega/X1_EM/fpgm/h256/ -tb 2 -lm HW -tn 5000 -aw 1800_2800 -v -o /home/mabon/Tiny_power/cnn_output/custom_prunded/HW/xmega/X1_EM/h256/fpgm/Train_X1_Test_X2
# %run "cnn/test.py" -i /home/mabon/Tiny_power/datasets/em/xmega/X2_K2_150k_L11.npz -m /home/mabon/Tiny_power/models/custom_prunded/HW/xmega/X1_EM/fpgm/h512/ -tb 2 -lm HW -tn 5000 -aw 1800_2800 -v -o /home/mabon/Tiny_power/cnn_output/custom_prunded/HW/xmega/X1_EM/h512/fpgm/Train_X1_Test_X2
# Out:
# 2023-07-25 17:33:40.886551: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /home/mabon/Tiny_power/code/CNN/cnn/test.py:116: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# loading pre-trained model...
# 2023-07-25 17:33:41.670646: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-25 17:33:41.671217: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Tiny_power/datasets/em/xmega/X1_K1_150k_L11.npz -m /home/mabon/Tiny_power/models/custom_prunded/HW/xmega/X1_EM/fpgm/h128/ -tb 2 -lm HW -tn 5000 -aw 1800_2800 -v -o /home/mabon/Tiny_power/cnn_output/custom_prunded/HW/xmega/X1_EM/h128/fpgm/Train_X1_Test_X1
# Out:
# 2023-07-25 14:29:52.346534: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /home/mabon/Tiny_power/code/CNN/cnn/test.py:116: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# loading pre-trained model...
# 2023-07-25 14:29:53.126734: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-25 14:29:53.127206: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...
