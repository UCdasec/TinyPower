# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L11/S2_K3_150k_L11.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/11
# Out:
# 2023-07-21 12:37:39.166890: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /home/mabon/Tiny_power/code/CNN/cnn/test.py:116: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# loading pre-trained model...
# 2023-07-21 12:37:39.988707: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 12:37:39.989328: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L00/S2_K3_150k_L00.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/00
# Out:
# loading pre-trained model...
# 2023-07-21 12:45:59.129206: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:45:59.129337: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:45:59.129573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:45:59.129598: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:45:59.129619: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L01/S2_K3_150k_L01.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/01
# Out:
# loading pre-trained model...
# 2023-07-21 12:48:41.979630: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:48:41.979760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:48:41.980003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:48:41.980028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:48:41.980048: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L02/S2_K3_150k_L02.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/02
# Out:
# loading pre-trained model...
# 2023-07-21 12:51:22.775721: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:51:22.775854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:51:22.776096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:51:22.776121: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:51:22.776139: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L10/S2_K3_150k_L10.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/10
# Out:
# loading pre-trained model...
# 2023-07-21 12:54:17.883150: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:54:17.883309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:54:17.883546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:54:17.883573: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:54:17.883592: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L12/S2_K3_150k_L12.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/12
# Out:
# loading pre-trained model...
# 2023-07-21 12:57:03.517451: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:57:03.517580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:57:03.517818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:57:03.517845: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:57:03.517865: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L20/S2_K3_150k_L20.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/20
# Out:
# loading pre-trained model...
# 2023-07-21 12:59:49.090813: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:59:49.090944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:59:49.091188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:59:49.091216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:59:49.091237: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L21/S2_K3_150k_L21.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/21
# Out:
# loading pre-trained model...
# 2023-07-21 12:40:26.466238: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:40:26.466369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:40:26.466615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:40:26.466642: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:40:26.466661: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# %run "cnn/test.py" -i /home/mabon/Cross_EM/datasets/stm_em/T2/S2_K3_150k_L22/S2_K3_150k_L22.npz -m /home/mabon/Cross_EM/models/stm/ID/S2_150K_L11 -tb 2 -lm ID -tn 5000 -aw 1200_2200 -o /home/mabon/Cross_EM/cnn_output/stm/ID/same_device/Train_S2_L11_Test_MULLOC/22
# Out:
# loading pre-trained model...
# 2023-07-21 12:43:09.197009: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-07-21 12:43:09.197172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-21 12:43:09.197415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-07-21 12:43:09.197441: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-21 12:43:09.197461: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...
